# %% [markdown]
# # Data Exploration & Model Development
#
# Use this notebook to explore the dataset, engineer features, evaluate models, and document your decisions.
#
# **This notebook is reviewed as part of your evaluation.** Show your thinking:
# - Explore distributions and correlations
# - Document feature engineering decisions
# - Compare at least two modeling approaches
# - Evaluate with appropriate metrics
#
# The dataset is at `../data/mtg_cards.csv`. See the README for feature descriptions and key challenges.
